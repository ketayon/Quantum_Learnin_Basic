# %%
from qiskit import *
from qiskit.tools.visualization import plot_histogram, array_to_latex, plot_bloch_multivector
# %matplotlib inline

# %%
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.cnot(0, 1)
circuit.measure_all()
circuit.draw(output='mpl')

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend=simulator).result()
plot_histogram(result.get_counts())

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit.tools.monitor import job_monitor

# %%
IBMQ.save_account('d5d3d8acb8dd380a2dcc2d2a1963904498905622013b91dde25dd8b1195daaa7b5b960af52ee50e246d62dcde12e415a90ff9a9de71a06c3d662a7c684dc503a')
provider = IBMQ.load_account()
# Out:
# /var/folders/_y/gpx6st7s77963mn1x58nrsf00000gn/T/ipykernel_41995/1568338593.py:1: DeprecationWarning: The package qiskit.providers.ibmq is being deprecated. Please see https://ibm.biz/provider_migration_guide to get instructions on how to migrate to qiskit-ibm-provider (https://github.com/Qiskit/qiskit-ibm-provider) and qiskit-ibm-runtime (https://github.com/Qiskit/qiskit-ibm-runtime).
#   IBMQ.save_account('d5d3d8acb8dd380a2dcc2d2a1963904498905622013b91dde25dd8b1195daaa7b5b960af52ee50e246d62dcde12e415a90ff9a9de71a06c3d662a7c684dc503a')
# ...

# %%
qcomp = provider.get_backend('ibmq_qasm_simulator')
job = execute(circuit, backend=qcomp)
job_monitor(job)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 qcomp = provider.get_backend('ibmq_qasm_simulator')
#       2 job = execute(circuit, backend=qcomp)
#       3 job_monitor(job)
#
# NameError: name 'provider' is not defined

# %%
qcomp_result = job.result()
plot_histogram(qcomp_result.get_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 qcomp_result = job.result()
#       2 plot_histogram(qcomp_result.get_counts())
#
# NameError: name 'job' is not defined

# %%
qcomp = provider.get_backend('ibmq_quito')
job = execute(circuit, backend=qcomp)
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
qcomp_result = job.result()
plot_histogram(qcomp_result.get_counts())
